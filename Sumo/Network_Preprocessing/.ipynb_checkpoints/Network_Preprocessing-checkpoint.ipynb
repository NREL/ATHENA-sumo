# %%
# %matplotlib inline

import matplotlib
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# ## Importing shapefile (.dbf file)

# %%
net_file_dbf = gpd.read_file('Data/poly_combined/poly_combined.dbf')

# %%
net_file_dbf.head()     # Looking at first few entries
# Out:
#       ID    LENGTH  DIR       LNKNM   NET_ID FAC_DIR                 STREET  \
# 0  13394  0.218089    0  40681300.0  13394.0    None         HIGH SCHOOL DR
# 1  13469  0.498383    0  30156600.0  13469.0    None             EDMONDS LN
# 2  13475  0.500352    0  30804500.0  13475.0    None            VALLEY PKWY
# 3  13653  0.170216    0  21100000.0  13653.0    None  FM3040 ROUND GROVE RD
# 4  13657  0.254158    1  25028002.0  13657.0    None              BS121H SB
#
#    TRDIR  FUNCL  DIVID  ...  TRXFER_EN  TSZ_EN  AREATY_EN  CYCLE__EN  \
# 0      2      4      2  ...        NaN    2360          3        NaN
# 1      2      3      2  ...        NaN    2389          3       78.0
# 2      2      3      1  ...        NaN    2387          3       78.0
# 3      2      2      1  ...        NaN   30155          4       60.0
# 4      1      2      1  ...        NaN    2444          4        NaN
#
#    STATIO_EN  lat_start    lat_end  lon_start    lon_end  \
# 0       None -96.996730 -96.992975  33.040070  33.040158
# 1       None -97.010280 -97.010460  33.034850  33.027620
# 2       None -97.018880 -97.019030  33.034949  33.027690
# 3       None -96.993965 -96.991034  33.003636  33.003636
# 4       None -96.993195 -96.994174  33.004732  33.001198
#
#                                             geometry
# 0  LINESTRING (-96.99673 33.04007, -96.9964740000...
# 1  LINESTRING (-97.01027999999999 33.03485, -97.0...
# 2  LINESTRING (-97.01888 33.034949, -97.018880999...
# 3  LINESTRING (-96.993965 33.003636, -96.99352500...
# 4  LINESTRING (-96.993195 33.004732, -96.993213 3...
#
# [5 rows x 107 columns]

# %%
# Display network
net_file_dbf.plot()

# %% [markdown]
# ## Selecting only useful column from file

# %%
list(net_file_dbf)
# Out:
# ['ID',
#  'LENGTH',
#  'DIR',
#  'LNKNM',
#  'NET_ID',
#  'FAC_DIR',
#  'STREET',
#  'TRDIR',
#  'FUNCL',
#  'DIVID',
#  'CNTRLA',
#  'CNTRLB',
#  'USERLENGTH',
#  'PKLNA',
#  'OPLNA',
#  'SPLTA',
#  'PKLNB',
#  'OPLNB',
#  'SPLTB',
#  'NHS',
#  'FFCS',
#  'FFCS_CLASS',
#  'ON_SYSTEM',
#  'TXDOT_DES',
#  'NTTA',
#  'MANAGED',
#  'CAPACITY',
#  'AMLN',
#  'PMLN',
#  'EXC_TRUCK',
#  'STREETA',
#  'STREETB',
#  'DATE',
#  'CODER',
#  'REASON',
#  'COMMENT',
#  'YEAR',
#  'INTVN',
#  'CORRIDOR',
#  'CONTROL',
#  'C_SECTION',
#  'COMB_C_S',
#  'TOLL_LINK_',
#  'AUX_LANES',
#  'TOTAL_LANE',
#  'THRULANES',
#  'TOLLROAD',
#  'TOLLA',
#  'TOLLB',
#  'TOLLA_AM',
#  'TOLLA_PM',
#  'TOLLA_OP',
#  'TOLLB_AM',
#  'TOLLB_PM',
#  'TOLLB_OP',
#  'TOLLMILE_A',
#  'TOLLMILE_P',
#  'TOLLMILE_O',
#  'FUNCL_2',
#  'TOLLMILE',
#  'RSA_ID',
#  'RSA_LINE1',
#  'RSA_LINE2',
#  'COMB_FSS',
#  'TEMP_09211',
#  'PKLN_AB',
#  'PKLN_BA',
#  'OPLN_AB',
#  'OPLN_BA',
#  'SPLT_AB',
#  'SPLT_BA',
#  'TOLLAM_AB',
#  'TOLLAM_BA',
#  'TOLLPM_AB',
#  'TOLLPM_BA',
#  'TOLLOP_AB',
#  'TOLLOP_BA',
#  'RTSTEMP',
#  'LINKMODE',
#  'A_PK',
#  'B_PK',
#  'C_PK',
#  'A_OP',
#  'B_OP',
#  'C_OP',
#  'MODEL_LENG',
#  'ID_ST',
#  'CENTRO_ST',
#  'PANDR_ST',
#  'TRXFER_ST',
#  'TSZ_ST',
#  'AREATY_ST',
#  'CYCLE__ST',
#  'STATIO_ST',
#  'ID_EN',
#  'CENTRO_EN',
#  'PANDR_EN',
#  'TRXFER_EN',
#  'TSZ_EN',
#  'AREATY_EN',
#  'CYCLE__EN',
#  'STATIO_EN',
#  'lat_start',
#  'lat_end',
#  'lon_start',
#  'lon_end',
#  'geometry']

# %%
mod_net_file_dbf = net_file_dbf[['ID','DIR','LENGTH','CNTRLA','CNTRLB','STREET','FUNCL','SPLTA','SPLTB','PKLNA','PKLNB','OPLNA','OPLNB','CNTRLA','CNTRLB','ID_ST', 'ID_EN','CAPACITY','geometry']]

# %%
mod_net_file_dbf.plot()

# %%
mod_net_file_dbf.head()
# Out:
#       ID  DIR    LENGTH  CNTRLA  CNTRLB                 STREET  FUNCL  SPLTA  \
# 0  13394    0  0.218089       6       7         HIGH SCHOOL DR      4     25
# 1  13469    0  0.498383       2       2             EDMONDS LN      3     35
# 2  13475    0  0.500352       2       2            VALLEY PKWY      3     35
# 3  13653    0  0.170216       1       2  FM3040 ROUND GROVE RD      2     50
# 4  13657    1  0.254158       1       1              BS121H SB      2     55
#
#    SPLTB  PKLNA  PKLNB  OPLNA  OPLNB  CNTRLA  CNTRLB  ID_ST  ID_EN  CAPACITY  \
# 0     25      1      1      1      1       6       7  54809  54808         0
# 1     35      2      2      2      2       2       2  54810  54811         0
# 2     35      2      2      2      2       2       2  54812  54813         0
# 3     50      3      3      3      3       1       2  54814  54815         0
# 4      0      2      0      2      0       1       1  54816  54817         0
#
#                                             geometry
# 0  LINESTRING (-96.99673 33.04007, -96.9964740000...
# 1  LINESTRING (-97.01027999999999 33.03485, -97.0...
# 2  LINESTRING (-97.01888 33.034949, -97.018880999...
# 3  LINESTRING (-96.993965 33.003636, -96.99352500...
# 4  LINESTRING (-96.993195 33.004732, -96.993213 3...

# %% [markdown]
# ## Modify Dir Column to contain B, F, T to mark sumo road directions
#
# #### B: Both ways  -- Sumo = 0
# #### F: Forward     -- Sumo = 1
# #### T: Backward  -- Sumo = -1

# %%
Dir = []

# %%
for i in range(len(mod_net_file_dbf['DIR'])):
    if int(mod_net_file_dbf['DIR'][i]) == 0: 
        Dir.append("B")
    elif int(mod_net_file_dbf['DIR'][i]) == 1:
        Dir.append("F")
    else: Dir.append("T")

# %%
mod_net_file_dbf.loc[:,'DIR'] = Dir
# Out:
# /Users/jugirumu/anaconda2/envs/Reg_Mobility/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
mod_net_file_dbf.head()
# Out:
#       ID DIR    LENGTH  CNTRLA  CNTRLB                 STREET  FUNCL  SPLTA  \
# 0  13394   B  0.218089       6       7         HIGH SCHOOL DR      4     25
# 1  13469   B  0.498383       2       2             EDMONDS LN      3     35
# 2  13475   B  0.500352       2       2            VALLEY PKWY      3     35
# 3  13653   B  0.170216       1       2  FM3040 ROUND GROVE RD      2     50
# 4  13657   F  0.254158       1       1              BS121H SB      2     55
#
#    SPLTB  PKLNA  PKLNB  OPLNA  OPLNB  CNTRLA  CNTRLB  ID_ST  ID_EN  CAPACITY  \
# 0     25      1      1      1      1       6       7  54809  54808         0
# 1     35      2      2      2      2       2       2  54810  54811         0
# 2     35      2      2      2      2       2       2  54812  54813         0
# 3     50      3      3      3      3       1       2  54814  54815         0
# 4      0      2      0      2      0       1       1  54816  54817         0
#
#                                             geometry
# 0  LINESTRING (-96.99673 33.04007, -96.9964740000...
# 1  LINESTRING (-97.01027999999999 33.03485, -97.0...
# 2  LINESTRING (-97.01888 33.034949, -97.018880999...
# 3  LINESTRING (-96.993965 33.003636, -96.99352500...
# 4  LINESTRING (-96.993195 33.004732, -96.993213 3...

# %% [markdown]
# ## Process Speed Limit Data

# %%
mod_net_file_dbf.loc[:,'SPEED'] = mod_net_file_dbf[['SPLTA','SPLTB']].max(axis=1)*0.44704
# Out:
# /Users/jugirumu/anaconda2/envs/Reg_Mobility/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)

# %%
mod_net_file_dbf.head()
# Out:
#       ID DIR    LENGTH  CNTRLA  CNTRLB                 STREET  FUNCL  SPLTA  \
# 0  13394   B  0.218089       6       7         HIGH SCHOOL DR      4     25
# 1  13469   B  0.498383       2       2             EDMONDS LN      3     35
# 2  13475   B  0.500352       2       2            VALLEY PKWY      3     35
# 3  13653   B  0.170216       1       2  FM3040 ROUND GROVE RD      2     50
# 4  13657   F  0.254158       1       1              BS121H SB      2     55
#
#    SPLTB  PKLNA  PKLNB  OPLNA  OPLNB  CNTRLA  CNTRLB  ID_ST  ID_EN  CAPACITY  \
# 0     25      1      1      1      1       6       7  54809  54808         0
# 1     35      2      2      2      2       2       2  54810  54811         0
# 2     35      2      2      2      2       2       2  54812  54813         0
# 3     50      3      3      3      3       1       2  54814  54815         0
# 4      0      2      0      2      0       1       1  54816  54817         0
#
#                                             geometry    SPEED
# 0  LINESTRING (-96.99673 33.04007, -96.9964740000...  11.1760
# 1  LINESTRING (-97.01027999999999 33.03485, -97.0...  15.6464
# 2  LINESTRING (-97.01888 33.034949, -97.018880999...  15.6464
# 3  LINESTRING (-96.993965 33.003636, -96.99352500...  22.3520
# 4  LINESTRING (-96.993195 33.004732, -96.993213 3...  24.5872

# %%
# Check if there is a link with speed limit zero
mod_net_file_dbf.loc[mod_net_file_dbf['SPEED'] == 0]
# Out:
# Empty GeoDataFrame
# Columns: [ID, DIR, LENGTH, CNTRLA, CNTRLB, STREET, FUNCL, SPLTA, SPLTB, PKLNA, PKLNB, OPLNA, OPLNB, CNTRLA, CNTRLB, ID_ST, ID_EN, CAPACITY, geometry, SPEED]
# Index: []

# %% [markdown]
# ## Processing Number of Lanes Data

# %%
mod_net_file_dbf.loc[:,'NOLANES'] = mod_net_file_dbf[['PKLNA','PKLNB']].sum(axis=1)

# %%
mod_net_file_dbf.loc[mod_net_file_dbf['NOLANES'] == 0]
# Out:
# Empty GeoDataFrame
# Columns: [ID, DIR, LENGTH, CNTRLA, CNTRLB, STREET, FUNCL, SPLTA, SPLTB, PKLNA, PKLNB, OPLNA, OPLNB, CNTRLA, CNTRLB, ID_ST, ID_EN, CAPACITY, geometry, SPEED, NOLANES]
# Index: []
#
# [0 rows x 21 columns]

# %%
mod_net_file_dbf.head()
# Out:
#       ID DIR    LENGTH  CNTRLA  CNTRLB                 STREET  FUNCL  SPLTA  \
# 0  13394   B  0.218089       6       7         HIGH SCHOOL DR      4     25
# 1  13469   B  0.498383       2       2             EDMONDS LN      3     35
# 2  13475   B  0.500352       2       2            VALLEY PKWY      3     35
# 3  13653   B  0.170216       1       2  FM3040 ROUND GROVE RD      2     50
# 4  13657   F  0.254158       1       1              BS121H SB      2     55
#
#    SPLTB  PKLNA  ...  OPLNA  OPLNB  CNTRLA  CNTRLB  ID_ST  ID_EN  CAPACITY  \
# 0     25      1  ...      1      1       6       7  54809  54808         0
# 1     35      2  ...      2      2       2       2  54810  54811         0
# 2     35      2  ...      2      2       2       2  54812  54813         0
# 3     50      3  ...      3      3       1       2  54814  54815         0
# 4      0      2  ...      2      0       1       1  54816  54817         0
#
#                                             geometry    SPEED  NOLANES
# 0  LINESTRING (-96.99673 33.04007, -96.9964740000...  11.1760        2
# 1  LINESTRING (-97.01027999999999 33.03485, -97.0...  15.6464        4
# 2  LINESTRING (-97.01888 33.034949, -97.018880999...  15.6464        4
# 3  LINESTRING (-96.993965 33.003636, -96.99352500...  22.3520        6
# 4  LINESTRING (-96.993195 33.004732, -96.993213 3...  24.5872        2
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Process Functional Class

# %%
Fun_c = []

for i in range(len(mod_net_file_dbf['FUNCL'])):
    if int(mod_net_file_dbf['FUNCL'][i]) == 1: 
        Fun_c.append("Freeway")
    elif int(mod_net_file_dbf['FUNCL'][i]) == 2:
        Fun_c.append("Principal Arterial")
    elif int(mod_net_file_dbf['FUNCL'][i]) == 3:
        Fun_c.append("Minor Arterial")
    elif int(mod_net_file_dbf['FUNCL'][i]) == 4:
        Fun_c.append("Collectors")
    elif int(mod_net_file_dbf['FUNCL'][i]) == 6:
        Fun_c.append("Freeway Ramp")
    elif int(mod_net_file_dbf['FUNCL'][i]) == 7:
        Fun_c.append("Fontage Road")
    elif int(mod_net_file_dbf['FUNCL'][i]) == 8:
        Fun_c.append("HOV")
    elif int(mod_net_file_dbf['FUNCL'][i]) == 9:
        Fun_c.append("Rail")

# %%
mod_net_file_dbf.loc[:,'FUNCL'] = Fun_c

# %%
mod_net_file_dbf.head()
# Out:
#       ID DIR    LENGTH  CNTRLA  CNTRLB                 STREET  \
# 0  13394   B  0.218089       6       7         HIGH SCHOOL DR
# 1  13469   B  0.498383       2       2             EDMONDS LN
# 2  13475   B  0.500352       2       2            VALLEY PKWY
# 3  13653   B  0.170216       1       2  FM3040 ROUND GROVE RD
# 4  13657   F  0.254158       1       1              BS121H SB
#
#                 FUNCL  SPLTA  SPLTB  PKLNA  ...  OPLNA  OPLNB  CNTRLA  CNTRLB  \
# 0          Collectors     25     25      1  ...      1      1       6       7
# 1      Minor Arterial     35     35      2  ...      2      2       2       2
# 2      Minor Arterial     35     35      2  ...      2      2       2       2
# 3  Principal Arterial     50     50      3  ...      3      3       1       2
# 4  Principal Arterial     55      0      2  ...      2      0       1       1
#
#    ID_ST  ID_EN  CAPACITY                                           geometry  \
# 0  54809  54808         0  LINESTRING (-96.99673 33.04007, -96.9964740000...
# 1  54810  54811         0  LINESTRING (-97.01027999999999 33.03485, -97.0...
# 2  54812  54813         0  LINESTRING (-97.01888 33.034949, -97.018880999...
# 3  54814  54815         0  LINESTRING (-96.993965 33.003636, -96.99352500...
# 4  54816  54817         0  LINESTRING (-96.993195 33.004732, -96.993213 3...
#
#      SPEED  NOLANES
# 0  11.1760        2
# 1  15.6464        4
# 2  15.6464        4
# 3  22.3520        6
# 4  24.5872        2
#
# [5 rows x 21 columns]

# %%
# Removing Duplicate columns
mod_net_file_dbf = mod_net_file_dbf.loc[:,~mod_net_file_dbf.columns.duplicated()]

# %%
mod_net_file_dbf.head()
# Out:
#       ID DIR    LENGTH  CNTRLA  CNTRLB                 STREET  \
# 0  13394   B  0.218089       6       7         HIGH SCHOOL DR
# 1  13469   B  0.498383       2       2             EDMONDS LN
# 2  13475   B  0.500352       2       2            VALLEY PKWY
# 3  13653   B  0.170216       1       2  FM3040 ROUND GROVE RD
# 4  13657   F  0.254158       1       1              BS121H SB
#
#                 FUNCL  SPLTA  SPLTB  PKLNA  PKLNB  OPLNA  OPLNB  ID_ST  ID_EN  \
# 0          Collectors     25     25      1      1      1      1  54809  54808
# 1      Minor Arterial     35     35      2      2      2      2  54810  54811
# 2      Minor Arterial     35     35      2      2      2      2  54812  54813
# 3  Principal Arterial     50     50      3      3      3      3  54814  54815
# 4  Principal Arterial     55      0      2      0      2      0  54816  54817
#
#    CAPACITY                                           geometry    SPEED  \
# 0         0  LINESTRING (-96.99673 33.04007, -96.9964740000...  11.1760
# 1         0  LINESTRING (-97.01027999999999 33.03485, -97.0...  15.6464
# 2         0  LINESTRING (-97.01888 33.034949, -97.018880999...  15.6464
# 3         0  LINESTRING (-96.993965 33.003636, -96.99352500...  22.3520
# 4         0  LINESTRING (-96.993195 33.004732, -96.993213 3...  24.5872
#
#    NOLANES
# 0        2
# 1        4
# 2        4
# 3        6
# 4        2

# %% [markdown]
# ## Change column names to match SUMO

# %%
save_net_file_dbf = mod_net_file_dbf[['ID','DIR','LENGTH','STREET','SPEED','NOLANES','FUNCL','ID_ST','ID_EN','CNTRLA','CNTRLB','geometry']]

# %%
save_net_file_dbf.head()
# Out:
#       ID DIR    LENGTH                 STREET    SPEED  NOLANES  \
# 0  13394   B  0.218089         HIGH SCHOOL DR  11.1760        2
# 1  13469   B  0.498383             EDMONDS LN  15.6464        4
# 2  13475   B  0.500352            VALLEY PKWY  15.6464        4
# 3  13653   B  0.170216  FM3040 ROUND GROVE RD  22.3520        6
# 4  13657   F  0.254158              BS121H SB  24.5872        2
#
#                 FUNCL  ID_ST  ID_EN  CNTRLA  CNTRLB  \
# 0          Collectors  54809  54808       6       7
# 1      Minor Arterial  54810  54811       2       2
# 2      Minor Arterial  54812  54813       2       2
# 3  Principal Arterial  54814  54815       1       2
# 4  Principal Arterial  54816  54817       1       1
#
#                                             geometry
# 0  LINESTRING (-96.99673 33.04007, -96.9964740000...
# 1  LINESTRING (-97.01027999999999 33.03485, -97.0...
# 2  LINESTRING (-97.01888 33.034949, -97.018880999...
# 3  LINESTRING (-96.993965 33.003636, -96.99352500...
# 4  LINESTRING (-96.993195 33.004732, -96.993213 3...

# %%
save_net_file_dbf.columns=['LINK_ID','DIR_TRAVEL','Length','ST_NAME','SPEED','NOLANES','FUNC_CLASS','REF_IN_ID','NREF_IN_ID','CNTRLA','CNTRLB','geometry']

# %%
list(save_net_file_dbf)
# Out:
# ['LINK_ID',
#  'DIR_TRAVEL',
#  'Length',
#  'ST_NAME',
#  'SPEED',
#  'NOLANES',
#  'FUNC_CLASS',
#  'REF_IN_ID',
#  'NREF_IN_ID',
#  'CNTRLA',
#  'CNTRLB',
#  'geometry']

# %%
save_net_file_dbf.head()
# Out:
#    LINK_ID DIR_TRAVEL    Length                ST_NAME    SPEED  NOLANES  \
# 0    13394          B  0.218089         HIGH SCHOOL DR  11.1760        2
# 1    13469          B  0.498383             EDMONDS LN  15.6464        4
# 2    13475          B  0.500352            VALLEY PKWY  15.6464        4
# 3    13653          B  0.170216  FM3040 ROUND GROVE RD  22.3520        6
# 4    13657          F  0.254158              BS121H SB  24.5872        2
#
#            FUNC_CLASS  REF_IN_ID  NREF_IN_ID  CNTRLA  CNTRLB  \
# 0          Collectors      54809       54808       6       7
# 1      Minor Arterial      54810       54811       2       2
# 2      Minor Arterial      54812       54813       2       2
# 3  Principal Arterial      54814       54815       1       2
# 4  Principal Arterial      54816       54817       1       1
#
#                                             geometry
# 0  LINESTRING (-96.99673 33.04007, -96.9964740000...
# 1  LINESTRING (-97.01027999999999 33.03485, -97.0...
# 2  LINESTRING (-97.01888 33.034949, -97.018880999...
# 3  LINESTRING (-96.993965 33.003636, -96.99352500...
# 4  LINESTRING (-96.993195 33.004732, -96.993213 3...

# %%
# Display new modified shapefile
save_net_file_dbf.plot()

# %% [markdown]
# ## Convertign Multipart to Singlepart
# ### The func below does not work, had to use QGIS

# %%
def multi2single(gpdf):
    gpdf_singlepoly = gpdf[gpdf.geometry.type == 'Polygon']
    gpdf_multipoly = gpdf[gpdf.geometry.type == 'MultiPolygon']

    for i, row in gpdf_multipoly.iterrows():
        Series_geometries = pd.Series(row.geometry)
        df = pd.concat([gp.GeoDataFrame(row, crs=gpdf_multipoly.crs).T]*len(Series_geometries), ignore_index=True)
        df['geometry']  = Series_geometries
        gpdf_singlepoly = pd.concat([gpdf_singlepoly, df])

    gpdf_singlepoly.reset_index(inplace=True, drop=True)
    return gpdf_singlepoly

# %%
linestring_dbf.head()
# Out:
# Empty GeoDataFrame
# Columns: [ID, LENGTH, DIR, LNKNM, NET_ID, FAC_DIR, STREET, TRDIR, FUNCL, DIVID, CNTRLA, CNTRLB, USERLENGTH, PKLNA, OPLNA, SPLTA, PKLNB, OPLNB, SPLTB, NHS, FFCS, FFCS_CLASS, ON_SYSTEM, TXDOT_DES, NTTA, MANAGED, CAPACITY, AMLN, PMLN, EXC_TRUCK, STREETA, STREETB, DATE, CODER, REASON, COMMENT, YEAR, INTVN, CORRIDOR, CONTROL, C_SECTION, COMB_C_S, TOLL_LINK_, AUX_LANES, TOTAL_LANE, THRULANES, TOLLROAD, TOLLA, TOLLB, TOLLA_AM, TOLLA_PM, TOLLA_OP, TOLLB_AM, TOLLB_PM, TOLLB_OP, TOLLMILE_A, TOLLMILE_P, TOLLMILE_O, FUNCL_2, TOLLMILE, RSA_ID, RSA_LINE1, RSA_LINE2, COMB_FSS, TEMP_09211, PKLN_AB, PKLN_BA, OPLN_AB, OPLN_BA, SPLT_AB, SPLT_BA, TOLLAM_AB, TOLLAM_BA, TOLLPM_AB, TOLLPM_BA, TOLLOP_AB, TOLLOP_BA, RTSTEMP, LINKMODE, A_PK, B_PK, C_PK, A_OP, B_OP, C_OP, MODEL_LENG, id_2, Route Name, XCoord, YCoord, BUFF_DIST, ORIG_FID, OBJECTID, street_2, streeta_2, streetb_2, Mode, Line, Mileage, Shape_Leng, ...]
# Index: []
#
# [0 rows x 101 columns]

# %% [markdown]
# ## Save new file to shapefile

# %%
save_net_file_dbf.to_file(driver = 'ESRI Shapefile', filename = 'Data/poly_combined/Sumo_Shapefile')
# Out:
# /Users/jugirumu/anaconda2/envs/Reg_Mobility/lib/python3.7/site-packages/geopandas/io/file.py:108: FionaDeprecationWarning: Use fiona.Env() instead.
#   with fiona.drivers():

# %%
# Save edge ids
f= open("Data/poly_combined/edge_ids.txt","w+")

for i in range(len(save_net_file_dbf['LINK_ID'])):
     f.write(str(save_net_file_dbf['LINK_ID'][i])+'\n')
        
f.close()

# %%
# Save from node ids
f= open("Data/poly_combined/start_node_ids.txt","w+")

from_nodes = list(set(save_net_file_dbf['REF_IN_ID']))

f.write(str(from_nodes[0]))

for i in range(1,len(from_nodes)):
    f.write(','+str(from_nodes[i]))
        
f.close()

# %%
# Save to node ids
f= open("Data/poly_combined/end_node_ids.txt","w+")

to_nodes = list(set(save_net_file_dbf['NREF_IN_ID']))

f.write(str(to_nodes[0]))
for i in range(1,len(to_nodes)):
     f.write(',' + str(to_nodes))
        
f.close()

# %%
# Save traffic light controlled node
sta_ttl_nodes = list(set(save_net_file_dbf.loc[save_net_file_dbf['CNTRLA'] == 2]['REF_IN_ID'].tolist()))
end_ttl_nodes = list(set(save_net_file_dbf.loc[save_net_file_dbf['CNTRLB'] == 2]['NREF_IN_ID'].tolist()))

# %%
combined_list = list(set(sta_ttl_nodes).union(set(end_ttl_nodes)))

# %%
print(len(combined_list))
# Out:
# 1019

# %%
# Save id of nodes controlled by traffic lights
f= open("Data/poly_combined/traffic_node_ids.txt","w+")

f.write(str(combined_list[0]))
for i in range(1,len(combined_list)):
     f.write(','+ str(combined_list[i]))
        
f.close()

# %%
# Nodes not controlled by traffic lights
no_ttl = list(set(from_nodes).union(set(to_nodes)) - set(combined_list))
f= open("Data/poly_combined/no_traffic_node_ids.txt","w+")

f.write(str(no_ttl[0]))

for i in range(1,len(no_ttl)):
     f.write(','+ str(no_ttl[i]))
        
f.close()

# %% [markdown]
# ## Conversion to Sumo network:
# ### --tls.set specifies nodes with traffic, while --tls.set is specify nodes without traffic lights
# Command below is run on command line, in Data/Sumo_Shapefile folder

# %% [markdown]
# $SUMO_HOME/bin/netconvert --shapefile-prefix Sumo_Shapefile --shapefile.street-id LINK_ID --shapefile.from-id REF_IN_ID --shapefile.to-id NREF_IN_ID --edges.join t --tls.guess t --tls.set "$(< ../traffic_node_ids.txt)" --tls.unset "$(< ../no_traffic_node_ids.txt)"

# %% [markdown]
# ## Divide the network obtained into different files: node file, edge file, traffic light file and connection file
# $SUMO_HOME/bin/netconvert --sumo-net-file net.net.xml --plain-output-prefix dfw --proj.plain-geo

# %% [markdown]
# ## Read in node file and change type of control at nodes to match the shapefiles

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('Data/poly_combined/Sumo_Shapefile/dfw.nod.xml')

# %%
# 1: no control  -- sumo: unregulated
# 2: traffic signal   -- sumo: traffic_light
# 5: Yield    -- sumo: priority_stop
# 6: all-way stop-controlled     -- sumo: allway_stop
# 7: two-way stop  -- sumo: guessed automatically by sumo

# for i in range(len(root_node)):
i = 0;
for child in tree.iter('node'):
    node_id = int(child.attrib['id'])
    node_type = child.attrib['type']

    entry_of_interest = save_net_file_dbf.loc[save_net_file_dbf['REF_IN_ID'] == node_id]
    if len(entry_of_interest) == 0:
        entry_of_interest = save_net_file_dbf.loc[save_net_file_dbf['NREF_IN_ID'] == node_id]
        type_in_shapefile = entry_of_interest['CNTRLB'].tolist()[0]
    else:
        type_in_shapefile = entry_of_interest['CNTRLA'].tolist()[0]

    
    if type_in_shapefile == 2 and node_type != 'traffic_light':
        print('traffic light conversion did not work, repeat step and check for error')
        child.set('type','traffic_light')
    elif type_in_shapefile == 1 and node_type != 'unregulated':
        child.set('type','unregulated')
    elif type_in_shapefile == 5 and node_type != 'priority':
        child.set('type','priority')
    elif type_in_shapefile == 7 and node_type != 'priority_stop':
        child.set('type','priority_stop')
    elif type_in_shapefile == 6 and node_type != 'allway_stop':
        child.set('type','allway_stop')
    else:
        print (type_in_shapefile, child.attrib['type'])
        if type_in_shapefile == 2: i += 1;
    
    #Remove the extra attributes from the tree
    child.attrib.pop('x')
    child.attrib.pop('y')
# Out:
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# traffic light conversion did not work, repeat step and check for error
# traffic light conversion did not work, repeat step and check for error
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# traffic light conversion did not work, repeat step and check for error
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 5 priority
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 5 priority
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 5 priority
# 5 priority
# 5 priority
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 5 priority
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# traffic light conversion did not work, repeat step and check for error
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 5 priority
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light
# 2 traffic_light

# %% [markdown]
# ## Need to check again why some traffic lights are not being set correctly

# %%
# Save the new node file
from xml.dom import minidom
new_node_file = 'Data/poly_combined/Sumo_Shapefile/corrected_small.nod.xml'
tree.write(new_node_file)

# %% [markdown]
# ## Modifying the node file type to match the shapefile type from the corrected node xml: new network is after -o
# $SUMO_HOME/bin/netconvert -s net.net.xml --node-files corrected_small.nod.xml -o corrected_nodes.net.xml
